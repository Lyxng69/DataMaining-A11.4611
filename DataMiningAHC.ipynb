# %% [markdown]
# <a href="https://colab.research.google.com/github/Lyxng69/DataMining-A11.4611/blob/main/DataMiningAHC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, single, complete, average, linkage

# %%
data = pd.read_excel("Data AHC.xlsx")
print(data)
# Out:
#    DTW  DTT  DMT  DDB
# 0    2    4    4    3
# 1    3    4    3    5
# 2    4    3    2    5
# 3    1    5    4    2
# 4    3    2    1    3

# %%
x = np.asarray(data)
print(x)
# Out:
# [[2 4 4 3]
#  [3 4 3 5]
#  [4 3 2 5]
#  [1 5 4 2]
#  [3 2 1 3]]

# %%
x = np.asarray(data)
print(x)
# Out:
# [[2 4 4 3]
#  [3 4 3 5]
#  [4 3 2 5]
#  [1 5 4 2]
#  [3 2 1 3]]

# %%
x = average(x)
y = single(x)
z = complete(x)
print(z)
print(y)
print(x)
# Out:
# [[0.         1.         1.41421356 2.        ]
#  [2.         3.         2.60024012 2.        ]
#  [4.         5.         7.40402966 4.        ]]
# [[0.         1.         1.41421356 2.        ]
#  [2.         3.         2.60024012 2.        ]
#  [4.         5.         5.26782688 4.        ]]
# [[0.         3.         1.73205081 2.        ]
#  [1.         2.         1.73205081 2.        ]
#  [4.         6.         3.05492646 3.        ]
#  [5.         7.         3.92742213 5.        ]]

# %%
plt.figure(figsize=(25,10))
plt.title('Dendrogram Hierarchical Klastering, complete Linkage')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(z)
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title('Dendrogram Hierarchical Klastering, single linkage')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(y)
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.title('Dendrogram Hierarchical Klastering, average linkage')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(x)
plt.show()
